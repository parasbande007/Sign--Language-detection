# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/ayush/miniconda3/lib/python3.11/site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow in /Users/ayush/miniconda3/lib/python3.11/site-packages (2.13.0)
# Requirement already satisfied: opencv-python in /Users/ayush/miniconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: mediapipe in /Users/ayush/miniconda3/lib/python3.11/site-packages (0.10.8)
# Collecting sklearn
#   Using cached sklearn-0.0.post11.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#
#       If the previous advice does not cover your use case, feel free to report it at
#       https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/ayush/miniconda3/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/ayush/miniconda3/lib/python3.11/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from scipy) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/ayush/miniconda3/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/ayush/miniconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from opencv-python) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in /Users/ayush/miniconda3/lib/python3.11/site-packages (0.10.8)
# Requirement already satisfied: absl-py in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (1.24.3)
# Requirement already satisfied: opencv-contrib-python in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (23.0)
# Requirement already satisfied: pillow>=8 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /Users/ayush/miniconda3/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/ayush/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1700831135.376933       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.64174086,  0.5222255 , -0.54290068, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.64174086,  0.5222255 , -0.54290068, ...,  0.        ,
#         0.        ,  0.        ])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1700823437.636888       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
[actions.shape[0]]
# Out:
# [3]

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 2s 32ms/step - loss: 1.2262 - categorical_accuracy: 0.3294
# Epoch 2/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2474 - categorical_accuracy: 0.4353
# Epoch 3/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1920 - categorical_accuracy: 0.4706
# Epoch 4/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1594 - categorical_accuracy: 0.2941
# Epoch 5/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0896 - categorical_accuracy: 0.3412
# Epoch 6/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.5011 - categorical_accuracy: 0.3529
# Epoch 7/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1265 - categorical_accuracy: 0.3294
# Epoch 8/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3110 - categorical_accuracy: 0.4353
# Epoch 9/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 1.0830 - categorical_accuracy: 0.3294
# Epoch 10/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0098 - categorical_accuracy: 0.5765
# Epoch 11/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8645 - categorical_accuracy: 0.5412
# Epoch 12/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9697 - categorical_accuracy: 0.4588
# Epoch 13/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9486 - categorical_accuracy: 0.4471
# Epoch 14/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8995 - categorical_accuracy: 0.5529
# Epoch 15/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8096 - categorical_accuracy: 0.5647
# Epoch 16/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7350 - categorical_accuracy: 0.7412
# Epoch 17/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7734 - categorical_accuracy: 0.6118
# Epoch 18/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7025 - categorical_accuracy: 0.6118
# Epoch 19/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6934 - categorical_accuracy: 0.6471
# Epoch 20/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6750 - categorical_accuracy: 0.6706
# Epoch 21/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6473 - categorical_accuracy: 0.7412
# Epoch 22/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6279 - categorical_accuracy: 0.7412
# Epoch 23/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6497 - categorical_accuracy: 0.7059
# Epoch 24/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6153 - categorical_accuracy: 0.7412
# Epoch 25/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5931 - categorical_accuracy: 0.7647
# Epoch 26/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5789 - categorical_accuracy: 0.7765
# Epoch 27/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5969 - categorical_accuracy: 0.7529
# Epoch 28/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6222 - categorical_accuracy: 0.7059
# Epoch 29/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6215 - categorical_accuracy: 0.7059
# Epoch 30/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5364 - categorical_accuracy: 0.7882
# Epoch 31/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7123 - categorical_accuracy: 0.6118
# Epoch 32/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5714 - categorical_accuracy: 0.7647
# Epoch 33/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6240 - categorical_accuracy: 0.6588
# Epoch 34/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6222 - categorical_accuracy: 0.6471
# Epoch 35/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6780 - categorical_accuracy: 0.6118
# Epoch 36/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6013 - categorical_accuracy: 0.6941
# Epoch 37/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5607 - categorical_accuracy: 0.7294
# Epoch 38/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4942 - categorical_accuracy: 0.8353
# Epoch 39/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4914 - categorical_accuracy: 0.8471
# Epoch 40/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4781 - categorical_accuracy: 0.8118
# Epoch 41/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4728 - categorical_accuracy: 0.8353
# Epoch 42/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.5114 - categorical_accuracy: 0.7882
# Epoch 43/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4586 - categorical_accuracy: 0.8588
# Epoch 44/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8883 - categorical_accuracy: 0.5765
# Epoch 45/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7141 - categorical_accuracy: 0.6941
# Epoch 46/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8864 - categorical_accuracy: 0.5412
# Epoch 47/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8688 - categorical_accuracy: 0.6353
# Epoch 48/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8160 - categorical_accuracy: 0.5647
# Epoch 49/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 2.1398 - categorical_accuracy: 0.5529
# Epoch 50/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1643 - categorical_accuracy: 0.3176
# Epoch 51/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.8037 - categorical_accuracy: 0.4353
# Epoch 52/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3125 - categorical_accuracy: 0.3294
# Epoch 53/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.1831 - categorical_accuracy: 0.3412
# Epoch 54/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 1.0066 - categorical_accuracy: 0.4941
# Epoch 55/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.0126 - categorical_accuracy: 0.3765
# Epoch 56/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0251 - categorical_accuracy: 0.3176
# Epoch 57/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9670 - categorical_accuracy: 0.4824
# Epoch 58/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.9883 - categorical_accuracy: 0.4824
# Epoch 59/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8681 - categorical_accuracy: 0.3294
# Epoch 60/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8633 - categorical_accuracy: 0.4824
# Epoch 61/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8663 - categorical_accuracy: 0.6706
# Epoch 62/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7187 - categorical_accuracy: 0.6353
# Epoch 63/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7740 - categorical_accuracy: 0.6588
# Epoch 64/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7914 - categorical_accuracy: 0.5765
# Epoch 65/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8008 - categorical_accuracy: 0.5529
# Epoch 66/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6909 - categorical_accuracy: 0.6118
# Epoch 67/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.7057 - categorical_accuracy: 0.6353
# Epoch 68/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6456 - categorical_accuracy: 0.6471
# Epoch 69/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6673 - categorical_accuracy: 0.6353
# Epoch 70/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5800 - categorical_accuracy: 0.6941
# Epoch 71/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5868 - categorical_accuracy: 0.7176
# Epoch 72/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5670 - categorical_accuracy: 0.7294
# Epoch 73/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5186 - categorical_accuracy: 0.7412
# Epoch 74/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6827 - categorical_accuracy: 0.6706
# Epoch 75/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5555 - categorical_accuracy: 0.7882
# Epoch 76/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5667 - categorical_accuracy: 0.7882
# Epoch 77/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5361 - categorical_accuracy: 0.7529
# Epoch 78/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5283 - categorical_accuracy: 0.7647
# Epoch 79/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5356 - categorical_accuracy: 0.7529
# Epoch 80/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4841 - categorical_accuracy: 0.8000
# Epoch 81/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4913 - categorical_accuracy: 0.8118
# Epoch 82/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4421 - categorical_accuracy: 0.8000
# Epoch 83/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4516 - categorical_accuracy: 0.8118
# Epoch 84/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3960 - categorical_accuracy: 0.8235
# Epoch 85/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3758 - categorical_accuracy: 0.8471
# Epoch 86/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4245 - categorical_accuracy: 0.8353
# Epoch 87/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4439 - categorical_accuracy: 0.7882
# Epoch 88/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4115 - categorical_accuracy: 0.8118
# Epoch 89/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4681 - categorical_accuracy: 0.8000
# Epoch 90/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4202 - categorical_accuracy: 0.8353
# Epoch 91/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4590 - categorical_accuracy: 0.8235
# Epoch 92/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4001 - categorical_accuracy: 0.8235
# Epoch 93/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4007 - categorical_accuracy: 0.8471
# Epoch 94/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3205 - categorical_accuracy: 0.8824
# Epoch 95/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3232 - categorical_accuracy: 0.8706
# Epoch 96/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3859 - categorical_accuracy: 0.8471
# Epoch 97/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3245 - categorical_accuracy: 0.8588
# Epoch 98/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3207 - categorical_accuracy: 0.8588
# Epoch 99/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3070 - categorical_accuracy: 0.8706
# Epoch 100/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2931 - categorical_accuracy: 0.8706
# Epoch 101/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2617 - categorical_accuracy: 0.8941
# Epoch 102/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2771 - categorical_accuracy: 0.8824
# Epoch 103/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2819 - categorical_accuracy: 0.8706
# Epoch 104/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3743 - categorical_accuracy: 0.8824
# Epoch 105/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4131 - categorical_accuracy: 0.8000
# Epoch 106/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3575 - categorical_accuracy: 0.8353
# Epoch 107/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2949 - categorical_accuracy: 0.8941
# Epoch 108/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2547 - categorical_accuracy: 0.9294
# Epoch 109/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2369 - categorical_accuracy: 0.8941
# Epoch 110/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2300 - categorical_accuracy: 0.9059
# Epoch 111/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3066 - categorical_accuracy: 0.8941
# Epoch 112/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3852 - categorical_accuracy: 0.8118
# Epoch 113/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2193 - categorical_accuracy: 0.8941
# Epoch 114/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2473 - categorical_accuracy: 0.8588
# Epoch 115/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1843 - categorical_accuracy: 0.9176
# Epoch 116/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2751 - categorical_accuracy: 0.9059
# Epoch 117/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2786 - categorical_accuracy: 0.9059
# Epoch 118/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7693 - categorical_accuracy: 0.7882
# Epoch 119/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4483 - categorical_accuracy: 0.8471
# Epoch 120/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4548 - categorical_accuracy: 0.7059
# Epoch 121/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8721 - categorical_accuracy: 0.4941
# Epoch 122/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.0011 - categorical_accuracy: 0.4941
# Epoch 123/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8969 - categorical_accuracy: 0.5059
# Epoch 124/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8727 - categorical_accuracy: 0.4471
# Epoch 125/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7901 - categorical_accuracy: 0.5294
# Epoch 126/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8009 - categorical_accuracy: 0.5765
# Epoch 127/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7191 - categorical_accuracy: 0.7529
# Epoch 128/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7208 - categorical_accuracy: 0.7765
# Epoch 129/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6498 - categorical_accuracy: 0.8000
# Epoch 130/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6170 - categorical_accuracy: 0.8235
# Epoch 131/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5647 - categorical_accuracy: 0.8235
# Epoch 132/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5343 - categorical_accuracy: 0.8235
# Epoch 133/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4219 - categorical_accuracy: 0.8588
# Epoch 134/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3343 - categorical_accuracy: 0.8941
# Epoch 135/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3343 - categorical_accuracy: 0.9059
# Epoch 136/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3505 - categorical_accuracy: 0.8824
# Epoch 137/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3508 - categorical_accuracy: 0.8706
# Epoch 138/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3086 - categorical_accuracy: 0.9059
# Epoch 139/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3011 - categorical_accuracy: 0.8706
# Epoch 140/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3475 - categorical_accuracy: 0.8471
# Epoch 141/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2564 - categorical_accuracy: 0.9176
# Epoch 142/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2849 - categorical_accuracy: 0.9059
# Epoch 143/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2589 - categorical_accuracy: 0.9294
# Epoch 144/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3831 - categorical_accuracy: 0.8353
# Epoch 145/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4160 - categorical_accuracy: 0.8118
# Epoch 146/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5189 - categorical_accuracy: 0.7765
# Epoch 147/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.5632 - categorical_accuracy: 0.8353
# Epoch 148/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5199 - categorical_accuracy: 0.7529
# Epoch 149/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6140 - categorical_accuracy: 0.8118
# Epoch 150/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5409 - categorical_accuracy: 0.7529
# Epoch 151/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5545 - categorical_accuracy: 0.7647
# Epoch 152/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6261 - categorical_accuracy: 0.7882
# Epoch 153/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1289 - categorical_accuracy: 0.5412
# Epoch 154/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8784 - categorical_accuracy: 0.5059
# Epoch 155/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3377 - categorical_accuracy: 0.3412
# Epoch 156/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.9116 - categorical_accuracy: 0.5294
# Epoch 157/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7770 - categorical_accuracy: 0.6353
# Epoch 158/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0620 - categorical_accuracy: 0.4588
# Epoch 159/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.0056 - categorical_accuracy: 0.4118
# Epoch 160/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.9702 - categorical_accuracy: 0.4588
# Epoch 161/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8754 - categorical_accuracy: 0.5412
# Epoch 162/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7662 - categorical_accuracy: 0.6588
# Epoch 163/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7498 - categorical_accuracy: 0.6706
# Epoch 164/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7196 - categorical_accuracy: 0.6706
# Epoch 165/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.7175 - categorical_accuracy: 0.6471
# Epoch 166/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6184 - categorical_accuracy: 0.7294
# Epoch 167/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6728 - categorical_accuracy: 0.6706
# Epoch 168/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6116 - categorical_accuracy: 0.7294
# Epoch 169/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6302 - categorical_accuracy: 0.7176
# Epoch 170/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5739 - categorical_accuracy: 0.7412
# Epoch 171/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5459 - categorical_accuracy: 0.7765
# Epoch 172/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5820 - categorical_accuracy: 0.7059
# Epoch 173/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5627 - categorical_accuracy: 0.7647
# Epoch 174/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5914 - categorical_accuracy: 0.7647
# Epoch 175/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.5874 - categorical_accuracy: 0.6706
# Epoch 176/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5446 - categorical_accuracy: 0.7882
# Epoch 177/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4889 - categorical_accuracy: 0.8000
# Epoch 178/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5219 - categorical_accuracy: 0.7529
# Epoch 179/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8654 - categorical_accuracy: 0.5882
# Epoch 180/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6208 - categorical_accuracy: 0.7765
# Epoch 181/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6565 - categorical_accuracy: 0.7059
# Epoch 182/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6414 - categorical_accuracy: 0.7294
# Epoch 183/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6185 - categorical_accuracy: 0.7647
# Epoch 184/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5847 - categorical_accuracy: 0.7765
# Epoch 185/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5602 - categorical_accuracy: 0.7882
# Epoch 186/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5218 - categorical_accuracy: 0.8118
# Epoch 187/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4869 - categorical_accuracy: 0.8235
# Epoch 188/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4548 - categorical_accuracy: 0.8118
# Epoch 189/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4563 - categorical_accuracy: 0.8471
# Epoch 190/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4755 - categorical_accuracy: 0.8235
# Epoch 191/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4892 - categorical_accuracy: 0.7882
# Epoch 192/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4015 - categorical_accuracy: 0.8235
# Epoch 193/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4181 - categorical_accuracy: 0.8471
# Epoch 194/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4509 - categorical_accuracy: 0.8588
# Epoch 195/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3693 - categorical_accuracy: 0.8706
# Epoch 196/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3313 - categorical_accuracy: 0.8941
# Epoch 197/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3325 - categorical_accuracy: 0.8824
# Epoch 198/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3379 - categorical_accuracy: 0.8824
# Epoch 199/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3087 - categorical_accuracy: 0.8824
# Epoch 200/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2914 - categorical_accuracy: 0.8706
# Epoch 201/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3166 - categorical_accuracy: 0.8706
# Epoch 202/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2708 - categorical_accuracy: 0.9059
# Epoch 203/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2496 - categorical_accuracy: 0.8824
# Epoch 204/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2574 - categorical_accuracy: 0.8941
# Epoch 205/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2695 - categorical_accuracy: 0.9294
# Epoch 206/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2670 - categorical_accuracy: 0.8941
# Epoch 207/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2501 - categorical_accuracy: 0.9059
# Epoch 208/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2847 - categorical_accuracy: 0.8941
# Epoch 209/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2396 - categorical_accuracy: 0.8941
# Epoch 210/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2596 - categorical_accuracy: 0.8941
# Epoch 211/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2469 - categorical_accuracy: 0.8824
# Epoch 212/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2403 - categorical_accuracy: 0.8941
# Epoch 213/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2740 - categorical_accuracy: 0.8824
# Epoch 214/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2786 - categorical_accuracy: 0.9059
# Epoch 215/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2398 - categorical_accuracy: 0.9059
# Epoch 216/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2372 - categorical_accuracy: 0.9059
# Epoch 217/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2279 - categorical_accuracy: 0.9059
# Epoch 218/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2876 - categorical_accuracy: 0.8706
# Epoch 219/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2840 - categorical_accuracy: 0.8941
# Epoch 220/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4152 - categorical_accuracy: 0.8471
# Epoch 221/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3560 - categorical_accuracy: 0.8706
# Epoch 222/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2921 - categorical_accuracy: 0.8941
# Epoch 223/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2787 - categorical_accuracy: 0.9176
# Epoch 224/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2442 - categorical_accuracy: 0.9176
# Epoch 225/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2339 - categorical_accuracy: 0.9412
# Epoch 226/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2274 - categorical_accuracy: 0.9059
# Epoch 227/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2621 - categorical_accuracy: 0.9059
# Epoch 228/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2886 - categorical_accuracy: 0.8706
# Epoch 229/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2439 - categorical_accuracy: 0.9176
# Epoch 230/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2090 - categorical_accuracy: 0.9412
# Epoch 231/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2455 - categorical_accuracy: 0.8824
# Epoch 232/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1969 - categorical_accuracy: 0.9176
# Epoch 233/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2409 - categorical_accuracy: 0.9059
# Epoch 234/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2287 - categorical_accuracy: 0.9176
# Epoch 235/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2498 - categorical_accuracy: 0.8824
# Epoch 236/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2344 - categorical_accuracy: 0.8941
# Epoch 237/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1741 - categorical_accuracy: 0.9294
# Epoch 238/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2555 - categorical_accuracy: 0.8706
# Epoch 239/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1933 - categorical_accuracy: 0.9176
# Epoch 240/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1971 - categorical_accuracy: 0.9176
# Epoch 241/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2210 - categorical_accuracy: 0.9294
# Epoch 242/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1758 - categorical_accuracy: 0.9176
# Epoch 243/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1745 - categorical_accuracy: 0.9529
# Epoch 244/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1741 - categorical_accuracy: 0.9412
# Epoch 245/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1630 - categorical_accuracy: 0.9412
# Epoch 246/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1430 - categorical_accuracy: 0.9529
# Epoch 247/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1918 - categorical_accuracy: 0.9412
# Epoch 248/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1748 - categorical_accuracy: 0.9529
# Epoch 249/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2277 - categorical_accuracy: 0.9529
# Epoch 250/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2161 - categorical_accuracy: 0.9529
# Epoch 251/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1977 - categorical_accuracy: 0.9412
# Epoch 252/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1859 - categorical_accuracy: 0.9529
# Epoch 253/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1865 - categorical_accuracy: 0.9529
# Epoch 254/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2042 - categorical_accuracy: 0.9176
# Epoch 255/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1838 - categorical_accuracy: 0.9529
# Epoch 256/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1688 - categorical_accuracy: 0.9412
# Epoch 257/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1641 - categorical_accuracy: 0.9412
# Epoch 258/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1615 - categorical_accuracy: 0.9529
# Epoch 259/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1568 - categorical_accuracy: 0.9176
# Epoch 260/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1733 - categorical_accuracy: 0.9529
# Epoch 261/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2675 - categorical_accuracy: 0.9059
# Epoch 262/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2861 - categorical_accuracy: 0.9176
# Epoch 263/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3058 - categorical_accuracy: 0.8706
# Epoch 264/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2624 - categorical_accuracy: 0.9176
# Epoch 265/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2441 - categorical_accuracy: 0.8824
# Epoch 266/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2709 - categorical_accuracy: 0.8824
# Epoch 267/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2415 - categorical_accuracy: 0.9059
# Epoch 268/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3101 - categorical_accuracy: 0.8588
# Epoch 269/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2492 - categorical_accuracy: 0.9059
# Epoch 270/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2559 - categorical_accuracy: 0.9059
# Epoch 271/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3302 - categorical_accuracy: 0.8941
# Epoch 272/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1786 - categorical_accuracy: 0.9294
# Epoch 273/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2006 - categorical_accuracy: 0.9176
# Epoch 274/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1937 - categorical_accuracy: 0.9529
# Epoch 275/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2003 - categorical_accuracy: 0.9294
# Epoch 276/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1710 - categorical_accuracy: 0.9412
# Epoch 277/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1652 - categorical_accuracy: 0.9412
# Epoch 278/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1584 - categorical_accuracy: 0.9294
# Epoch 279/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1595 - categorical_accuracy: 0.9294
# Epoch 280/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1550 - categorical_accuracy: 0.9176
# Epoch 281/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1467 - categorical_accuracy: 0.9294
# Epoch 282/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2282 - categorical_accuracy: 0.9294
# Epoch 283/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3944 - categorical_accuracy: 0.8706
# Epoch 284/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4205 - categorical_accuracy: 0.8471
# Epoch 285/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3027 - categorical_accuracy: 0.8824
# Epoch 286/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1723 - categorical_accuracy: 0.9412
# Epoch 287/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1743 - categorical_accuracy: 0.9412
# Epoch 288/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1584 - categorical_accuracy: 0.8941
# Epoch 289/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1571 - categorical_accuracy: 0.9294
# Epoch 290/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1435 - categorical_accuracy: 0.9647
# Epoch 291/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1505 - categorical_accuracy: 0.9294
# Epoch 292/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1370 - categorical_accuracy: 0.9412
# Epoch 293/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1154 - categorical_accuracy: 0.9647
# Epoch 294/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1237 - categorical_accuracy: 0.9647
# Epoch 295/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1080 - categorical_accuracy: 0.9647
# Epoch 296/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1173 - categorical_accuracy: 0.9647
# Epoch 297/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1070 - categorical_accuracy: 0.9529
# Epoch 298/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0988 - categorical_accuracy: 0.9529
# Epoch 299/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0954 - categorical_accuracy: 0.9529
# Epoch 300/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0945 - categorical_accuracy: 0.9647
# Epoch 301/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0960 - categorical_accuracy: 0.9647
# Epoch 302/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1346 - categorical_accuracy: 0.9412
# Epoch 303/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1033 - categorical_accuracy: 0.9529
# Epoch 304/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0945 - categorical_accuracy: 0.9647
# Epoch 305/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.1067 - categorical_accuracy: 0.9529
# Epoch 306/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0908 - categorical_accuracy: 0.9647
# Epoch 307/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1099 - categorical_accuracy: 0.9412
# Epoch 308/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1854 - categorical_accuracy: 0.9529
# Epoch 309/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3477 - categorical_accuracy: 0.8824
# Epoch 310/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.0082 - categorical_accuracy: 0.8235
# Epoch 311/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 4.6014 - categorical_accuracy: 0.3059
# Epoch 312/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 1.8695 - categorical_accuracy: 0.3176
# Epoch 313/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 1.2318 - categorical_accuracy: 0.4000
# Epoch 314/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0010 - categorical_accuracy: 0.5059
# Epoch 315/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8552 - categorical_accuracy: 0.6706
# Epoch 316/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7414 - categorical_accuracy: 0.6706
# Epoch 317/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.7028 - categorical_accuracy: 0.7059
# Epoch 318/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6897 - categorical_accuracy: 0.7529
# Epoch 319/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8582 - categorical_accuracy: 0.7059
# Epoch 320/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.8698 - categorical_accuracy: 0.4941
# Epoch 321/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.7603 - categorical_accuracy: 0.6000
# Epoch 322/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6835 - categorical_accuracy: 0.8000
# Epoch 323/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6101 - categorical_accuracy: 0.7412
# Epoch 324/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5460 - categorical_accuracy: 0.8000
# Epoch 325/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.5852 - categorical_accuracy: 0.6471
# Epoch 326/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4608 - categorical_accuracy: 0.8118
# Epoch 327/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4257 - categorical_accuracy: 0.7882
# Epoch 328/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4701 - categorical_accuracy: 0.8235
# Epoch 329/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.5422 - categorical_accuracy: 0.8000
# Epoch 330/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.5093 - categorical_accuracy: 0.8000
# Epoch 331/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4584 - categorical_accuracy: 0.8824
# Epoch 332/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4620 - categorical_accuracy: 0.8706
# Epoch 333/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4296 - categorical_accuracy: 0.8471
# Epoch 334/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4378 - categorical_accuracy: 0.8706
# Epoch 335/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3826 - categorical_accuracy: 0.9294
# Epoch 336/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.3286 - categorical_accuracy: 0.8706
# Epoch 337/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3071 - categorical_accuracy: 0.9059
# Epoch 338/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2709 - categorical_accuracy: 0.9294
# Epoch 339/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2372 - categorical_accuracy: 0.9412
# Epoch 340/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2498 - categorical_accuracy: 0.9412
# Epoch 341/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2187 - categorical_accuracy: 0.9294
# Epoch 342/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2037 - categorical_accuracy: 0.9529
# Epoch 343/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1667 - categorical_accuracy: 0.9529
# Epoch 344/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3296 - categorical_accuracy: 0.8706
# Epoch 345/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4174 - categorical_accuracy: 0.8824
# Epoch 346/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2225 - categorical_accuracy: 0.9294
# Epoch 347/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2524 - categorical_accuracy: 0.9059
# Epoch 348/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2829 - categorical_accuracy: 0.8941
# Epoch 349/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.3093 - categorical_accuracy: 0.8588
# Epoch 350/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.4792 - categorical_accuracy: 0.8235
# Epoch 351/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3690 - categorical_accuracy: 0.8471
# Epoch 352/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.4089 - categorical_accuracy: 0.8471
# Epoch 353/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3669 - categorical_accuracy: 0.8706
# Epoch 354/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.3641 - categorical_accuracy: 0.8588
# Epoch 355/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2764 - categorical_accuracy: 0.9176
# Epoch 356/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2602 - categorical_accuracy: 0.9176
# Epoch 357/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2877 - categorical_accuracy: 0.8706
# Epoch 358/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2537 - categorical_accuracy: 0.9176
# Epoch 359/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.2043 - categorical_accuracy: 0.9529
# Epoch 360/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2336 - categorical_accuracy: 0.9059
# Epoch 361/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1963 - categorical_accuracy: 0.9412
# Epoch 362/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1633 - categorical_accuracy: 0.9529
# Epoch 363/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1677 - categorical_accuracy: 0.9412
# Epoch 364/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1563 - categorical_accuracy: 0.9294
# Epoch 365/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1410 - categorical_accuracy: 0.9412
# Epoch 366/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1693 - categorical_accuracy: 0.9294
# Epoch 367/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1539 - categorical_accuracy: 0.9412
# Epoch 368/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1232 - categorical_accuracy: 0.9647
# Epoch 369/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1258 - categorical_accuracy: 0.9647
# Epoch 370/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1120 - categorical_accuracy: 0.9412
# Epoch 371/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1279 - categorical_accuracy: 0.9647
# Epoch 372/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1143 - categorical_accuracy: 0.9765
# Epoch 373/1000
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0777 - categorical_accuracy: 0.9688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 213ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'thanks'

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_train)
# Out:
# 3/3 [==============================] - 0s 12ms/step

# %%
ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[54,  2],
#         [ 1, 28]],
#
#        [[57,  0],
#         [ 2, 26]],
#
#        [[56,  1],
#         [ 0, 28]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9647058823529412

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1700831321.341456       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 9ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 12ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 10ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 28
#      25 sequence = sequence[-30:]
#      27 if len(sequence) == 30:
# ---> 28     res = model.predict(np.expand_dims(sequence, axis=0))[0]
#      29     print(actions[np.argmax(res)])
#      32 #3. Viz logic
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:2521, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2512     except ValueError:
#    2513         warnings.warn(
#    2514             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2515             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2518             stacklevel=2,
#    2519         )
# -> 2521 data_handler = data_adapter.get_data_handler(
#    2522     x=x,
#    2523     batch_size=batch_size,
#    2524     steps_per_epoch=steps,
#    2525     initial_epoch=0,
#    2526     epochs=1,
#    2527     max_queue_size=max_queue_size,
#    2528     workers=workers,
#    2529     use_multiprocessing=use_multiprocessing,
#    2530     model=self,
#    2531     steps_per_execution=self._steps_per_execution,
#    2532 )
#    2534 # Container that configures and calls `tf.keras.Callback`s.
#    2535 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1678, in get_data_handler(*args, **kwargs)
#    1676         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678 return DataHandler(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1285, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1282     self._steps_per_execution = steps_per_execution
#    1284 adapter_cls = select_data_adapter(x, y)
# -> 1285 self._adapter = adapter_cls(
#    1286     x,
#    1287     y,
#    1288     batch_size=batch_size,
#    1289     steps=steps_per_epoch,
#    1290     epochs=epochs - initial_epoch,
#    1291     sample_weights=sample_weight,
#    1292     shuffle=shuffle,
#    1293     max_queue_size=max_queue_size,
#    1294     workers=workers,
#    1295     use_multiprocessing=use_multiprocessing,
#    1296     distribution_strategy=tf.distribute.get_strategy(),
#    1297     model=model,
#    1298     pss_evaluation_shards=pss_evaluation_shards,
#    1299 )
#    1301 strategy = tf.distribute.get_strategy()
#    1303 self._current_step = 0
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:355, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     351     return flat_dataset
#     353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#     359     def shuffle_batch(*batch):
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:396, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     391 def grab_batch(i, data):
#     392     return tf.nest.map_structure(
#     393         lambda d: tf.gather(d, i, axis=0), data
#     394     )
# --> 396 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     398 # Default optimizations are disabled to avoid the overhead of
#     399 # (unnecessary) input pipeline graph serialization and deserialization
#     400 options = tf.data.Options()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:2278, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2274 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2275 # dataset_ops).
#    2276 # pylint: disable=g-import-not-at-top,protected-access
#    2277 from tensorflow.python.data.ops import map_op
# -> 2278 return map_op._map_v2(
#    2279     self,
#    2280     map_func,
#    2281     num_parallel_calls=num_parallel_calls,
#    2282     deterministic=deterministic,
#    2283     name=name)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/map_op.py:40, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
# ---> 40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#      43       num_parallel_calls=num_parallel_calls,
#      44       deterministic=deterministic,
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/map_op.py:148, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146 self._input_dataset = input_dataset
#     147 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148 self._map_func = structured_function.StructuredFunctionWrapper(
#     149     map_func,
#     150     self._transformation_name(),
#     151     dataset=input_dataset,
#     152     use_legacy_function=use_legacy_function)
#     153 if deterministic is None:
#     154   self._deterministic = "default"
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:272, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     265       warnings.warn(
#     266           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     267           "option is set, this option does not apply to tf.data functions. "
#     268           "To force eager execution of tf.data functions, please use "
#     269           "`tf.data.experimental.enable_debug_mode()`.")
#     270     fn_factory = trace_tf_function(defun_kwargs)
# --> 272 self._function = fn_factory()
#     273 # There is no graph to add in eager mode.
#     274 add_to_graph &= not context.executing_eagerly()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1189, in Function.get_concrete_function(self, *args, **kwargs)
#    1187 def get_concrete_function(self, *args, **kwargs):
#    1188   # Implements GenericFunction.get_concrete_function.
# -> 1189   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1190   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1191   return concrete
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1169, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1167   if self._variable_creation_fn is None:
#    1168     initializers = []
# -> 1169     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1170     self._initialize_uninitialized_variables(initializers)
#    1172 if self._created_variables:
#    1173   # In this case we have created variables on the first call, so we run the
#    1174   # version which is guaranteed to never create variables.
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:694, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_fn._name = self._name  # pylint: disable=protected-access
#     692 # Force the definition of the function for these arguments
#     693 self._concrete_variable_creation_fn = (
# --> 694     self._variable_creation_fn    # pylint: disable=protected-access
#     695     ._get_concrete_function_internal_garbage_collected(
#     696         *args, **kwds))
#     698 def invalid_creator_scope(*unused_args, **unused_kwds):
#     699   """Disables variable creation."""
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:176, in TracingCompiler._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     174 """Returns a concrete function which cleans up its graph function."""
#     175 with self._lock:
# --> 176   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     177 return concrete_function
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:171, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     168   args = self.input_signature
#     169   kwargs = {}
# --> 171 return self._maybe_define_function(args, kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:398, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     395 args = placeholder_bound_args.args
#     396 kwargs = placeholder_bound_args.kwargs
# --> 398 concrete_function = self._create_concrete_function(
#     399     args, kwargs, func_graph)
#     401 # TODO(b/263520817): Remove access to private attribute.
#     402 graph_capture_container = concrete_function.graph.function_captures
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:304, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     301 else:
#     302   arg_names = base_arg_names
# --> 304 concrete_function = monomorphic_function.ConcreteFunction(
#     305     func_graph_module.func_graph_from_py_func(
#     306         self._name,
#     307         self._python_function,
#     308         args,
#     309         kwargs,
#     310         None,
#     311         func_graph=func_graph,
#     312         arg_names=arg_names,
#     313         capture_by_value=self._capture_by_value,
#     314         create_placeholders=False),
#     315     self._function_attributes,
#     316     spec=self.function_spec,
#     317     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     318     # scope. This is not the default behavior since it gets used in some
#     319     # places (like Keras) where the FuncGraph lives longer than the
#     320     # ConcreteFunction.
#     321     shared_func_graph=False)
#     322 return concrete_function
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1066, in ConcreteFunction.__init__(self, func_graph, attrs, shared_func_graph, spec)
#    1060   self._garbage_collector = ConcreteFunctionGarbageCollector(func_graph)
#    1062 # Pairs of forward and backward functions used for computing gradients.
#    1063 #
#    1064 # These each get a reference to the FuncGraph deleter since they use the
#    1065 # FuncGraph directly.
# -> 1066 self._delayed_rewrite_functions = _DelayedRewriteGradientFunctions(
#    1067     func_graph, self._attrs, self._garbage_collector)
#    1068 self._first_order_tape_functions = {}
#    1069 self._higher_order_tape_functions = {}
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:155, in _DelayedRewriteGradientFunctions.__init__(self, func_graph, attrs, func_graph_deleter)
#     153 self._cached_function_pairs = {}
#     154 self._func_graph = func_graph
# --> 155 self._inference_function = atomic_function.from_func_graph(
#     156     _inference_name(self._func_graph.name), self._func_graph,
#     157     self._func_graph.inputs, self._func_graph.outputs, attrs)
#     158 self._attrs = attrs
#     159 self._gradient_name = None
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:357, in from_func_graph(name, graph, inputs, outputs, attrs)
#     354 def from_func_graph(name, graph, inputs, outputs, attrs):
#     355   """Initializes an AtomicFunction from FuncGraph with transforms."""
# --> 357   atomic = from_func_graph_no_transforms(name, graph, inputs, outputs, attrs)
#     358   for transform in FUNCTION_TRANSFORMS:
#     359     atomic = transform(atomic)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:427, in from_func_graph_no_transforms(name, graph, inputs, outputs, attrs, overwrite)
#     424 if overwrite and bound_context.has_function(name):
#     425   bound_context.remove_function(name)
# --> 427 bound_context.add_c_function(fn)
#     428 pywrap_tf_session.TF_DeleteFunction(fn)
#     430 graph_artifacts = GraphArtifacts(
#     431     control_captures=graph.function_captures.control,
#     432     graph=graph,
#     433     stateful_ops=tuple(op for op in operations if op._is_stateful),  # pylint: disable=protected-access
#     434 )
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1342, in Context.add_c_function(self, c_func)
#    1333 def add_c_function(self, c_func):
#    1334   """Add a C API TF_Function to the context.
#    1335
#    1336   Once added, the function (identified by its name) can be executed like any
#    (...)
#    1340     c_func: A wrapped TF_Function (returned from TF_GraphToFunction_wrapper).
#    1341   """
# -> 1342   self.ensure_initialized()
#    1343   pywrap_tfe.TFE_ContextAddFunction(self._handle, c_func)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:571, in Context.ensure_initialized(self)
#     568     self._context_devices = context_devices
#     569     pywrap_tfe.TF_DeleteDeviceList(device_list)
# --> 571 def ensure_initialized(self):
#     572   """Initialize handle and devices if not already done so."""
#     573   if self._initialized:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
sequence.reverse()

# %%
len(sequence)
# Out:
# 31

# %%
sequence.append('def')

# %%
sequence.reverse()

# %%
sequence[-30:]
# Out:
# [array([ 0.57743901,  0.21182619, -0.63310856, ...,  0.03741421,
#         -0.13113692, -0.07273996]),
#  array([ 0.57739836,  0.21219486, -0.58255398, ..., -0.02773996,
#         -0.14026053, -0.06489833]),
#  array([ 0.57665879,  0.2112124 , -0.6256668 , ...,  0.09993266,
#         -0.18187162, -0.05699627]),
#  array([ 0.57160932,  0.21577343, -0.66905785, ...,  0.29324722,
#         -0.14001642, -0.06954197]),
#  array([ 0.56918216,  0.21446016, -0.70590228, ...,  0.32360744,
#         -0.10764098, -0.0820649 ]),
#  array([ 0.56826729,  0.21508779, -0.69437593, ...,  0.20646815,
#         -0.11942005, -0.08926594]),
#  array([ 0.57206178,  0.21168844, -0.61931312, ..., -0.03294475,
#         -0.08478735, -0.08460969]),
#  array([ 0.57401031,  0.20957765, -0.62436152, ..., -0.07007301,
#         -0.06107096, -0.02893455]),
#  array([ 0.57730806,  0.20399725, -0.59468055, ..., -0.09952599,
#          0.03100631, -0.08391143]),
#  array([ 0.57774127,  0.20573345, -0.63533443, ...,  0.09478609,
#         -0.09770647, -0.04840356]),
#  array([ 0.55253768,  0.19927582, -0.63574183, ...,  0.33636135,
#         -0.06544954, -0.1083987 ]),
#  array([ 0.50093049,  0.19919214, -0.59741759, ...,  0.30083865,
#         -0.0609422 , -0.11775359]),
#  array([ 0.54705614,  0.19868895, -0.60057801, ...,  0.07239237,
#          0.00697261, -0.07663193]),
#  array([ 0.57320315,  0.19526573, -0.58022153, ..., -0.1093    ,
#          0.12043712, -0.07141841]),
#  array([ 0.58478045,  0.19526085, -0.5814327 , ..., -0.1402766 ,
#          0.14040795, -0.01860758]),
#  array([ 0.58831799,  0.19529514, -0.59417921, ..., -0.05580254,
#          0.03608409, -0.03625821]),
#  array([ 0.58681905,  0.20482704, -0.80893028, ...,  0.30945867,
#          0.02156711, -0.04021573]),
#  array([ 0.58616769,  0.20242678, -1.12582147, ...,  0.35928616,
#          0.77460396, -0.04648414]),
#  array([ 0.58949101,  0.16515012, -0.917548  , ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58973563,  0.14817783, -0.88780606, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58917022,  0.10803543, -0.89325839, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58721578,  0.09791618, -0.87665188, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5862686 ,  0.09739805, -0.87781602, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.58504766,  0.10271069, -0.86515647, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.57870811,  0.15503468, -0.86002415, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.5668782 ,  0.18055074, -0.85725272, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.55955613,  0.19765055, -0.85576785, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.55366391,  0.2052063 , -0.84491998, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.55173361,  0.20351045, -0.84423029, ...,  0.        ,
#          0.        ,  0.        ]),
#  array([ 0.55135918,  0.20326099, -0.84377307, ...,  0.        ,
#          0.        ,  0.        ])]

# %%
res[np.argmax(res)] > threshold
# Out:
# True
